# %%
import numpy as np
import matplotlib
import pandas as pd

# %%
diamonds = pd.read_csv(r"C:\Users\avira\OneDrive\Desktop\Aviral - ml\Aviral\Phase 2\Exploring Data\archive\diamonds.csv")
print(diamonds.shape)
diamonds.head(5)
# Out:
# (53940, 10)
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#histograms
diamonds.hist(column='carat',
              figsize=(8,8),
              bins=50,
              color='blue')
# Out:
# array([[<Axes: title={'center': 'carat'}>]], dtype=object)

# %%
#boxplots
diamonds.boxplot(column="price",
                 by='clarity')
# Out:
# <Axes: title={'center': 'price'}, xlabel='clarity'>

# %%
diamonds.plot(kind="scatter",     # Create a scatterplot
              x="carat",          # Put carat on the x axis
              y="price",          # Put price on the y axis
              figsize=(10,10),
              ylim=(0,20000),
              )
# Out:
# <Axes: xlabel='carat', ylabel='price'>
